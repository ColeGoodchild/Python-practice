# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 3, 7, 9)
tuple3 = (True, False, False)

# Tuples can be of any type

# %%
# Or contain different data types

tuple1 = ("abc", 34, True, 40, "man")

# %%
# Checking if an item exists
tuple1 = ("apple", "banana", "cherry")
if "apple" in thistuple:
    print("Yes, 'apple' is present.")
# Out:
# Yes, 'apple' is present.

# %%
# We can't change tuple values, but we can convert it to a list, change something, then revert it back to a tuple
tuple1 = ("apple", "banana", "cherry")
y = list(tuple1)
y[1] = "kiwi"
tuple1 = tuple(y)
print(tuple1)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
# Adding tuples to tuples
tuple1 = ("apple", "banana", "cherry")
y = ("Orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'Orange')

# %%
# Looping through with while looops

tuple1 = ("apple", "banana", "cherry")
i = 0
while i < len(tuple1):
    print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
